# %% [markdown]
# ## Lab 11. Exploratory Analysis
# Exploratory analysis helps us to know more about the datasets before geovisualization. The explorative analysis also help us to get new insight for the dataset. This tutorial is used to do exploratory analysis on spatial data. We will use modules of `seaborn` and `pysal` to create histogram, box map, scatter, correlation analysis, spatial autocorrelation, and choropleth mapping.

# %% [markdown]
# ### 1. Prepare and import required modules
#
# Prepare the python module, the new modeuls is `seaborn`. If you have `seaborn` not installed, just go to your virtual environment in Anaconda and type `conda install seaborn` in your virtual environment.

# %%
import seaborn
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.colors import Normalize
from matplotlib import cm
import cartopy.crs as ccrs

# %% [markdown]
# ### 2. Prepare the data
# Read the geojson file of blood lead level data and check the data

# %%
blood_gdf = gpd.read_file('data/blood_lead.geojson')
blood_gdf.head(15)
# Out:
#      census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0   42101000100           0         0.0       100.0         0.0
# 1   42101000200           1         NaN       109.0         NaN
# 2   42101000300           1         NaN       110.0         NaN
# 3   42101000401           1         NaN        61.0         NaN
# 4   42101000402           0         0.0        41.0         0.0
# 5   42101000500           1         NaN        49.0         NaN
# 6   42101000600           0         0.0        24.0         0.0
# 7   42101000700           0         0.0        57.0         0.0
# 8   42101000801           1         NaN        57.0         NaN
# 9   42101000803           0         0.0        63.0         0.0
# 10  42101000804           0         0.0        86.0         0.0
# 11  42101000901           0         0.0        21.0         0.0
# 12  42101000902           1         NaN        62.0         NaN
# 13  42101001001           0         0.0        68.0         0.0
# 14  42101001002           0         0.0        82.0         0.0
#
#                                              geometry
# 0   (POLYGON ((-75.14147213273969 39.9517072267047...
# 1   (POLYGON ((-75.162377698504 39.9576545523082, ...
# 2   (POLYGON ((-75.17820482839041 39.9598134132842...
# 3   (POLYGON ((-75.1729917788024 39.9546437050483,...
# 4   (POLYGON ((-75.1633313650233 39.9533392100125,...
# 5   (POLYGON ((-75.1634037710016 39.9533470650473,...
# 6   (POLYGON ((-75.1639387712695 39.9508740649554,...
# 7   (POLYGON ((-75.17349243240059 39.9520618460711...
# 8   (POLYGON ((-75.1774238003255 39.9505040569508,...
# 9   (POLYGON ((-75.1774238003255 39.9505040569508,...
# 10  (POLYGON ((-75.1648475938443 39.9470084055078,...
# 11  (POLYGON ((-75.1642667713794 39.9493480641678,...
# 12  (POLYGON ((-75.1530893693124 39.9460042685997,...
# 13  (POLYGON ((-75.15313476730221 39.9457870640091...
# 14  (POLYGON ((-75.150342248005 39.943739726991, -...

# %%
blood_gdf['perc_5plus'].describe
blood_gdf.describe
# Out:
# <bound method NDFrame.describe of       census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0    42101000100           0         0.0       100.0         0.0
# 1    42101000200           1         NaN       109.0         NaN
# 2    42101000300           1         NaN       110.0         NaN
# 3    42101000401           1         NaN        61.0         NaN
# 4    42101000402           0         0.0        41.0         0.0
# ..           ...         ...         ...         ...         ...
# 375  42101980200           1         NaN         NaN         NaN
# 376  42101980700           1         NaN         NaN         NaN
# 377  42101980800           1         NaN         NaN         NaN
# 378  42101980900           1         NaN         NaN         NaN
# 379  42101989100           1         NaN         NaN         NaN
#
#                                               geometry
# 0    (POLYGON ((-75.14147213273969 39.9517072267047...
# 1    (POLYGON ((-75.162377698504 39.9576545523082, ...
# 2    (POLYGON ((-75.17820482839041 39.9598134132842...
# 3    (POLYGON ((-75.1729917788024 39.9546437050483,...
# 4    (POLYGON ((-75.1633313650233 39.9533392100125,...
# ..                                                 ...
# 375  (POLYGON ((-75.05635673803801 40.0876645665025...
# 376  (POLYGON ((-75.1351492487008 39.9286294339812,...
# 377  (POLYGON ((-75.25592702256429 39.9781297321056...
# 378  (POLYGON ((-75.2016453002315 39.937568298222, ...
# 379  (POLYGON ((-74.99255713701911 40.035771800404,...
#
# [380 rows x 6 columns]>

# %% [markdown]
# The max, min, and std values of the variable

# %%
maxvalue = blood_gdf['perc_5plus'].max()
minvalue = blood_gdf['perc_5plus'].min()
stand = blood_gdf['perc_5plus'].std()

print('The max, min, and standard deviation values are:', maxvalue, minvalue, stand)
# Out:
# The max, min, and standard deviation values are: 17.6 0.0 3.9393103190846737

# %% [markdown]
# The number of null data

# %%
import pandas as pd

pd.isnull(blood_gdf['perc_5plus']).sum()
# Out:
# 126

# %% [markdown]
# ### 3. Choropleth mapping
# Create the choropleth map of the blood lead level data in Philadelphia

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
# from matplotlib import cm


f, ax = plt.subplots(1, figsize=(12, 12), subplot_kw={'aspect':'equal'})

blood_lead_gdf = gpd.read_file('data/blood_lead.geojson')

# change the projection to local projection of Philadelphia
blood_lead_gdf_phily = blood_lead_gdf.to_crs({'init': 'epsg:3651'})
blood_lead_gdf_phily = blood_lead_gdf


cmap = plt.cm.get_cmap('YlGnBu', 6) #alternative GnBu

# plot the choropleth map of blood lead in Philadelphia
blood_lead_gdf_phily.plot(column='perc_5plus', 
                         cmap='YlGnBu', 
                         edgecolor='0.5',
                         ax = ax,
                         linewidth=0.5,
                         scheme='equal_interval')

# create a color bar for the map
norm = Normalize(vmin=blood_lead_gdf['perc_5plus'].min(), vmax=blood_lead_gdf['perc_5plus'].max())
n_cmap = cm.ScalarMappable(norm=norm, cmap=cmap)
cbar = ax.get_figure().colorbar(n_cmap, orientation='horizontal', fraction=0.046, pad=0.0, shrink=0.4)
cbar.ax.set_xlabel('Blood level')

ax.set_axis_off()
plt.axis('equal')
# plt.savefig('plot.png', bbox_inches='tight', pad_inches=0.1, dpi=1000)

plt.show()

# %% [markdown]
# ### 4. Plot the histograms

# %% [markdown]
# Prepare the data, this is not necessary because you have already read the geojson file

# %%
blood_lead_gdf = gpd.read_file('data/blood_lead.geojson')
blood_lead_gdf.head()
# Out:
#     census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0  42101000100           0         0.0       100.0         0.0
# 1  42101000200           1         NaN       109.0         NaN
# 2  42101000300           1         NaN       110.0         NaN
# 3  42101000401           1         NaN        61.0         NaN
# 4  42101000402           0         0.0        41.0         0.0
#
#                                             geometry
# 0  (POLYGON ((-75.14147213273969 39.9517072267047...
# 1  (POLYGON ((-75.162377698504 39.9576545523082, ...
# 2  (POLYGON ((-75.17820482839041 39.9598134132842...
# 3  (POLYGON ((-75.1729917788024 39.9546437050483,...
# 4  (POLYGON ((-75.1633313650233 39.9533392100125,...

# %% [markdown]
# There are some records have NaN data, therefore, we need to drop it for further analysis

# %%
blood_lead_gdf_valid = blood_lead_gdf_phily.dropna(how='any',axis=0)

# %% [markdown]
# Plot the histogram of column `perc_5plus`

# %%
import seaborn as sns

# set the label size of the histogram
plt.rcParams["axes.labelsize"] = 15

# get the column of perc_5plus
perc_5plus = blood_lead_gdf_valid['perc_5plus']

# plot the histogram distribution 
with sns.axes_style("white"):
    sns.distplot(perc_5plus)

# %% [markdown]
# histogram for column of `num_bll_5p`

# %%
num_bll_5p = blood_lead_gdf_valid['num_bll_5p']

with sns.axes_style("white"):
    sns.distplot(num_bll_5p)

# %% [markdown]
# Selecting data using Labels (Column Headings). Only get the data for columns of "num_bll_5p" and "perc_5plus"

# %%
plot_df.head()
# Out:
#    num_bll_5p  perc_5plus
# 0         0.0         0.0
# 4         0.0         0.0
# 6         0.0         0.0
# 7         0.0         0.0
# 9         0.0         0.0

# %% [markdown]
# ### 5. Boxplot
# We can plot the boxplot of data to check the distributions of different variables in our dataframe. **Note**: slice two columns from `blood_lead_gdf_valid` and create a new dataframe.

# %%
# slice two column from `blood_lead_gdf_valid` and create a new dataframe
plot_df = blood_lead_gdf_valid[['num_bll_5p', 'perc_5plus']]

# %% [markdown]
# Plot the boxplot and assign different colors to different variables

# %%
# set the size of the plot
plt.figure(figsize=(6, 8))

sns.set_style("white")
sns.set(style="ticks", palette="pastel")

sns.boxplot(data=plot_df, palette=["m", "g"])
plt.title("Box maps")
# Out:
# Text(0.5, 1.0, 'Box maps')

# %% [markdown]
# ### 6. Scatterplots
# Plot the scatter of multiple variables

# %%
plt.figure(figsize=(6, 6))

ax = sns.scatterplot(x="num_bll_5p", y="perc_5plus", data=plot_df, color='k')

# %% [markdown]
# Plot the scatter and the histograms together

# %%
sns.set(style="white")

with sns.axes_style("white"):
    sns.jointplot(x=perc_5plus, y=num_bll_5p, data=df, height=7, space=0) #kind="hex",

# %% [markdown]
# By setting the kind, you can create different types of scatter plot, #“scatter” | “reg” | “resid” | “kde” | “hex”

# %%
sns.set(style="white")

with sns.axes_style("white"):
    sns.jointplot(x=perc_5plus, y=num_bll_5p, data=df, kind="reg", height=7, space=0)

# %% [markdown]
# ### 7. Calculating correlations
# You can use pandas to do very basic correlation analysis, https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html

# %%
# pearson correlation
plot_df.corr(method = 'pearson')
# Out:
#             num_bll_5p  perc_5plus
# num_bll_5p    1.000000    0.757234
# perc_5plus    0.757234    1.000000

# %%
# spearman correlation or rank correlation
plot_df.corr(method = 'spearman')
# Out:
#             num_bll_5p  perc_5plus
# num_bll_5p    1.000000    0.822991
# perc_5plus    0.822991    1.000000

# %% [markdown]
# ### 8. Spatial Autocorrelation
#
# Our brains are very powerful pattern recognition machines. However, sometimes they can be too powerful and lead us to detect false positives, or patterns where there are no statistical patterns. This is a particular concern when dealing with visualization of irregular polygons of differning sizes and shapes.

# %% [markdown]
# #### Attribute Similarity
# We have already encountered spatial weights in a previous notebook. In spatial autocorrelation analysis, the spatial weights are used to formalize the notion of spatial similarity. As we have seen there are many ways to define spatial weights, here we will use queen contiguity:

# %%
import libpysal as lps

# fill the nan with mean value of the column
blood_lead_gdf['perc_5plus'].fillna((blood_lead_gdf['perc_5plus'].mean()), inplace=True)

# create the queen spatial weight
df = blood_lead_gdf
wq =  lps.weights.Queen.from_dataframe(df)
wq.transform = 'r'

# %%
y = blood_lead_gdf['perc_5plus']
ylag = lps.weights.lag_spatial(wq, y)
ylag
# Out:
# array([ 2.92933071,  2.92933071,  3.34780652,  1.17173228,  3.90577428,
#         1.67390326,  1.46466535,  1.95288714,  1.46466535,  3.51519685,
#         1.95288714,  2.92933071,  2.34346457,  2.92933071,  0.        ,
#         4.18475816,  4.39399606,  3.90577428,  3.34780652,  4.62514061,
#         5.46456693,  4.39399606,  2.92933071,  3.26266404,  4.07637795,
#         5.20577428,  5.04346457,  5.8083802 ,  5.12514061,  5.68346457,
#         5.17519685,  3.89656918,  4.15288714,  3.88346457,  4.54346457,
#         4.13622047,  4.96466535,  5.07173228,  5.51266404,  6.03695163,
#         4.74311024,  4.56955381,  4.80288714,  4.13333333,  3.78966535,
#         4.59599738,  4.99183071,  5.22692913,  5.26266404,  4.81955381,
#         4.80949803,  4.77933071,  5.54599738,  5.26346457,  5.85866142,
#         3.90577428,  6.17980877,  4.39173228,  2.68966535,  4.41955381,
#         5.33966535,  4.76      ,  4.58333333,  4.6       ,  8.28571429,
#         6.525     ,  5.97980877,  7.35173228,  7.07980877,  8.33333333,
#         8.525     ,  7.38333333,  8.7       ,  6.27716535,  6.18449803,
#         7.49311024,  7.15      ,  8.6       ,  7.16666667,  7.63333333,
#         6.31466535,  7.05      ,  6.02      ,  6.46983268,  6.35173228,
#         5.01428571,  5.62514061,  5.50433071,  3.90577428,  4.57244094,
#         4.08346457,  4.32514061,  5.97933071,  5.67644357,  6.6       ,
#         6.        ,  5.5597769 ,  5.85866142,  2.92933071,  6.37173228,
#         5.26666667,  5.61666667,  6.38      ,  6.1       ,  5.87173228,
#         5.69409449,  5.075     ,  5.02      ,  4.01466535,  3.63966535,
#         4.96      ,  4.99      ,  6.98      ,  6.46      ,  5.25      ,
#         7.11466535,  7.26466535,  6.15123735,  5.14346457,  4.51466535,
#         4.60433071,  1.95288714,  1.95288714,  1.46466535,  5.07047244,
#         5.44692913,  5.75519685,  4.63352081,  3.14346457,  4.01466535,
#         5.70494938,  3.92933071,  5.42644357,  7.41466535,  7.68966535,
#         6.96      ,  7.69409449,  5.55371204,  5.63258968,  4.80494938,
#         4.825     ,  5.33352081,  5.83519685,  5.53622047,  5.93695163,
#         7.55      ,  9.025     , 12.38      , 10.4875    ,  9.10651794,
#         5.99173228,  5.12644357,  5.16552306,  5.46666667,  6.1625    ,
#         6.53695163,  6.66666667,  7.35      ,  8.8       ,  8.88333333,
#         8.92      , 10.5       ,  9.8       , 10.83333333, 10.83333333,
#        10.48333333,  7.63622047, 10.225     , 12.83333333, 13.6       ,
#        12.98      , 11.0375    ,  8.72      ,  7.18      ,  6.2       ,
#         7.925     ,  6.8875    ,  7.65714286, 10.05173228,  5.35714286,
#         4.925     ,  6.39173228,  6.98346457,  7.17244094,  6.25      ,
#         6.67777778,  6.8375    ,  7.14      ,  6.84      ,  7.675     ,
#        10.27142857, 11.21428571, 13.6       , 14.11666667, 11.22857143,
#        12.13333333, 12.44      , 11.34169649,  6.62644357,  4.04346457,
#         6.29399606,  5.85866142,  5.30346457,  5.30346457,  5.88221785,
#         4.88221785,  5.90577428,  4.71519685,  5.85866142,  5.85866142,
#         5.04190101,  4.88221785,  4.68692913,  7.21683071,  5.73221785,
#         6.34399606,  7.57933071,  8.78333333,  8.35961755,  7.67933071,
#         9.5597769 ,  9.31173228, 10.54      , 10.3083802 , 10.57980877,
#         8.32644357,  9.16      ,  8.46666667,  9.2       ,  7.73173228,
#         6.15288714,  5.95371204,  3.93622047,  4.53519685,  6.09399606,
#         3.90577428,  5.8       ,  5.29399606,  4.96166339,  5.08228346,
#         5.71899606,  5.27173228,  6.48346457,  5.78571429,  7.625     ,
#         7.25      ,  6.70247469,  6.30577428,  6.85288714,  6.33622047,
#         5.66466535,  8.17980877,  7.99173228,  6.34      ,  7.53622047,
#         6.21173228,  7.48818898,  7.97644357,  7.68571429,  8.35      ,
#        10.11666667, 11.79409449,  9.91173228,  9.97142857, 11.64      ,
#         9.38      ,  8.51666667,  6.4       ,  4.725     ,  4.9       ,
#         8.49173228,  6.45      ,  7.25714286,  8.64      ,  4.55714286,
#         6.75288714,  5.45555556,  5.95      ,  8.225     ,  5.35714286,
#         3.65      ,  3.16666667,  3.82644357,  4.90433071,  4.77519685,
#         4.19311024,  4.27390326,  4.01173228,  3.9       ,  3.2       ,
#         3.76466535,  5.02170979,  4.35433071,  3.50247469,  3.10247469,
#         2.25      ,  2.83233268,  4.25      ,  4.325     ,  4.78233268,
#         2.96552306,  3.79173228,  3.74346457,  3.1097769 ,  3.80346457,
#         5.3359955 ,  4.60433071,  2.82644357,  3.90433071,  4.49066367,
#         5.00577428,  4.26166339,  3.96955381,  5.34692913,  4.63519685,
#         5.14692913,  5.26899606,  5.85866142,  4.88221785,  3.90577428,
#         5.85866142,  3.51519685,  2.92933071,  3.34780652,  5.02170979,
#         4.68692913,  3.51519685,  5.02170979,  4.68692913,  4.88221785,
#         4.74190101,  5.85866142,  4.39399606,  4.18475816,  2.34346457,
#         1.95288714,  5.85866142,  3.66166339,  4.88221785,  2.92933071,
#         3.90577428,  3.90577428,  3.51519685,  4.39399606,  2.92933071,
#         4.39399606,  2.92933071,  3.67703412,  3.56266404,  4.39399606,
#         2.34346457,  5.09699803,  1.95288714,  5.53966535,  4.88221785,
#         3.90577428,  4.88771091,  6.02692913,  6.73942632,  5.85866142,
#         5.63173228,  4.43666339,  7.76399825,  4.90690766,  4.39399606,
#         6.76811024,  6.25      ,  4.68692913,  5.07933071,  4.39399606,
#         5.98228346,  7.08966535,  4.06666667,  6.18911811,  5.35618673,
#         4.47782972,  4.65618673,  5.69409449,  4.99288714,  4.29519685])

# %% [markdown]
# We have already encountered spatial weights in a previous notebook. In spatial autocorrelation analysis, the spatial weights are used to formalize the notion of spatial similarity. As we have seen there are many ways to define spatial weights, here we will use queen contiguity:

# %%
import mapclassify as mc
ylagq5 = mc.Quantiles(ylag, k=5)
ylagq5
# Out:
#                Quantiles
#
# Lower            Upper             Count
# ========================================
#          x[i] <=  4.074               76
#  4.074 < x[i] <=  4.992               76
#  4.992 < x[i] <=  5.859               78
#  5.859 < x[i] <=  7.358               74
#  7.358 < x[i] <= 14.117               76

# %%
f, ax = plt.subplots(1, figsize=(9, 9))
df.assign(cl=ylagq5.yb).plot(column='cl', categorical=True, \
        k=5, cmap='GnBu', linewidth=0.1, ax=ax, \
        edgecolor='white', legend=True)
ax.set_axis_off()
plt.title("Spatial Lag Median Price (Quintiles)")

plt.show()

# %%
df.head()
# Out:
#     census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0  42101000100           0         0.0       100.0    0.000000
# 1  42101000200           1         NaN       109.0    5.858661
# 2  42101000300           1         NaN       110.0    5.858661
# 3  42101000401           1         NaN        61.0    5.858661
# 4  42101000402           0         0.0        41.0    0.000000
#
#                                             geometry  lag_median_pri  \
# 0  (POLYGON ((-75.14147213273969 39.9517072267047...        2.929331
# 1  (POLYGON ((-75.162377698504 39.9576545523082, ...        2.929331
# 2  (POLYGON ((-75.17820482839041 39.9598134132842...        3.347807
# 3  (POLYGON ((-75.1729917788024 39.9546437050483,...        1.171732
# 4  (POLYGON ((-75.1633313650233 39.9533392100125,...        3.905774
#
#    lag_median_lead     yb
# 0         2.929331  0 Low
# 1         2.929331  0 Low
# 2         3.347807  0 Low
# 3         1.171732  0 Low
# 4         3.905774  0 Low

# %%
df['lag_median_lead'] = ylag
f,ax = plt.subplots(1,2,figsize=(2.16*4,4))
df.plot(column='perc_5plus', ax=ax[0], edgecolor='k',
        scheme="quantiles",  k=5, cmap='GnBu')
ax[0].axis(df.total_bounds[np.asarray([0,2,1,3])])
ax[0].set_title("Blood lead")
df.plot(column='lag_median_lead', ax=ax[1], edgecolor='k',
        scheme='quantiles', cmap='GnBu', k=5)
ax[1].axis(df.total_bounds[np.asarray([0,2,1,3])])
ax[1].set_title("Spatial Lag Blood lead")
ax[0].axis('off')
ax[1].axis('off')
plt.show()

# %% [markdown]
# However, we still have the challenge of visually associating the value of the prices in a neighborhod with the value of the spatial lag of values for the focal unit. The latter is a weighted average of homicide rates in the focal county's neighborhood.
#
# To complement the geovisualization of these associations we can turn to formal statistical measures of spatial autocorrelation.

# %%
wq.transform = 'r'
y = df['perc_5plus']

# %% [markdown]
# Install module of esda, `pip install esda`. Calculate the morans'I coefficient

# %%
import esda 

np.random.seed(12345)

# calculate the moran's I coefficient
mi = esda.moran.Moran(y, wq)
mi.I
# Out:
# 0.4671604794874547

# %%
import seaborn as sbn
sbn.kdeplot(mi.sim, shade=True)
plt.vlines(mi.I, 0, 1, color='r')
plt.vlines(mi.EI, 0,1)
plt.xlabel("Moran's I")
# Out:
# Text(0.5, 0, "Moran's I")

# %% [markdown]
# P value of the moran's I

# %%
mi.p_sim
# Out:
# 0.001

# %% [markdown]
# ## Reference
# - Seabor Gallery, https://seaborn.pydata.org/examples/index.html
# - Pandas data manipulation, https://datacarpentry.org/python-ecology-lesson/03-index-slice-subset/
# - Spatial Analysis using Pysal, https://nbviewer.jupyter.org/github/pysal/esda/blob/master/notebooks/Spatial%20Autocorrelation%20for%20Areal%20Unit%20Data.ipynb
